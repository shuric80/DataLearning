# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.datasets import load_boston
from sklearn.preprocessing import scale
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from numpy import linspace

# %%
dataset = load_boston()
target = dataset.target
data = scale(dataset.data)

# %%
kf  = KFold(random_state=42, n_splits=5, shuffle=True)

# %%
for index_train, index_test in kf.split(data):
    X_train, y_train = data[index_train], target[index_train]
    X_test, y_test = data[index_test], target[index_test]

# %%
result = dict()
for p in linspace(1, 10, 200):
    neigh = KNeighborsRegressor( n_neighbors=5, weights='distance', metric='minkowski',p=p )
    neigh.fit(X_train, y_train)
    cross = cross_val_score(neigh, X_train, y_train, scoring='neg_mean_squared_error')
    result[p] = cross.mean()
# Out:
# /home/shuric/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/shuric/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/shuric/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# ...

# %%
max_value = max(result.values())
for key, value in result.items():
    if value == max_value:
        print(key)
# Out:
# 1.1809045226130652
